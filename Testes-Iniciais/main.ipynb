# %%
from github import Github
import pandas as pd

# Conecte-se à API do GitHub
g = Github("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")

# Função para buscar repositórios
def search_repositories(query, stars=100):
    repos = g.search_repositories(query=f"{query} stars:>{stars}")
    repo_data = []

    for repo in repos:
        repo_data.append({
            'name': repo.full_name,
            'description': repo.description,
            'stars': repo.stargazers_count,
            'language': repo.language,
            'forks': repo.forks_count,
            'url': repo.html_url,
            'created_at': repo.created_at,
            'updated_at': repo.updated_at
        })

    return repo_data

# Buscar repositórios com React e Angular
react_repos = search_repositories("React")
angular_repos = search_repositories("Angular")
material_repos = search_repositories("Material UI")

# Exibir resultados
print("React Repositories:")
for repo in react_repos:
    print(repo)

print("\nAngular Repositories:")
for repo in angular_repos:
    print(repo)

# Salvar resultados em CSV
df_react = pd.DataFrame(react_repos)
df_angular = pd.DataFrame(angular_repos)
df_material_ui = pd.DataFrame(material_repos)

df_react.to_csv("react_repositories.csv", index=False)
df_angular.to_csv("angular_repositories.csv", index=False)
df_material_ui.to_csv('material_ui_repos.csv', index=False)
# Out:
# Request GET /search/repositories?q=React+stars%3A%3E100&page=31 failed with 403: Forbidden
# Setting next backoff to 22.195755s
# Request GET /search/repositories?q=Angular+stars%3A%3E100&page=27 failed with 403: Forbidden
# Setting next backoff to 23.312079s
# React Repositories:
# {'name': 'facebook/react', 'description': 'The library for web and native user interfaces.', 'stars': 227432, 'language': 'JavaScript', 'forks': 46388, 'url': 'https://github.com/facebook/react', 'created_at': datetime.datetime(2013, 5, 24, 16, 15, 54, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 32, 13, tzinfo=datetime.timezone.utc)}
# {'name': 'typescript-cheatsheets/react', 'description': 'Cheatsheets for experienced React developers getting started with TypeScript', 'stars': 45014, 'language': 'JavaScript', 'forks': 4087, 'url': 'https://github.com/typescript-cheatsheets/react', 'created_at': datetime.datetime(2018, 6, 2, 4, 8, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 57, 22, tzinfo=datetime.timezone.utc)}
# {'name': 'duxianwei520/react', 'description': ' React+webpack+redux+ant design+axios+less全家桶后台管理框架', 'stars': 5054, 'language': 'JavaScript', 'forks': 1751, 'url': 'https://github.com/duxianwei520/react', 'created_at': datetime.datetime(2016, 12, 2, 13, 8, 43, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 15, 58, 54, tzinfo=datetime.timezone.utc)}
# {'name': 'primer/react', 'description': "An implementation of GitHub's Primer Design System using React", 'stars': 3104, 'language': 'TypeScript', 'forks': 533, 'url': 'https://github.com/primer/react', 'created_at': datetime.datetime(2018, 2, 17, 0, 9, 5, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 0, 8, 16, tzinfo=datetime.timezone.utc)}
# {'name': 'discountry/react', 'description': 'React docs in Chinese | React 中文文档翻译', 'stars': 1272, 'language': 'JavaScript', 'forks': 550, 'url': 'https://github.com/discountry/react', 'created_at': datetime.datetime(2017, 5, 9, 15, 9, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 7, 10, 41, tzinfo=datetime.timezone.utc)}
# {'name': 'react-redux-antd-es6/react', 'description': '基于react的企业后台管理开发框架', 'stars': 1162, 'language': 'JavaScript', 'forks': 474, 'url': 'https://github.com/react-redux-antd-es6/react', 'created_at': datetime.datetime(2016, 12, 28, 7, 44, 4, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 1, 8, 55, tzinfo=datetime.timezone.utc)}
# {'name': 'HackYourFuture/React', 'description': 'This repository contains all the material for the HackYourFuture module "React.js: Building dynamic UIs with modern JavaScript"', 'stars': 366, 'language': 'JavaScript', 'forks': 688, 'url': 'https://github.com/HackYourFuture/React', 'created_at': datetime.datetime(2017, 6, 6, 9, 58, 23, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 11, 5, 5, 17, tzinfo=datetime.timezone.utc)}
# {'name': 'Cathy0807/react', 'description': '京东首页构建', 'stars': 863, 'language': 'JavaScript', 'forks': 453, 'url': 'https://github.com/Cathy0807/react', 'created_at': datetime.datetime(2016, 11, 2, 10, 18, 45, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 11, 4, 35, tzinfo=datetime.timezone.utc)}
# {'name': 'ysymyth/ReAct', 'description': '[ICLR 2023] ReAct: Synergizing Reasoning and Acting in Language Models', 'stars': 1862, 'language': 'Jupyter Notebook', 'forks': 187, 'url': 'https://github.com/ysymyth/ReAct', 'created_at': datetime.datetime(2022, 11, 13, 19, 51, 9, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 12, 18, 52, tzinfo=datetime.timezone.utc)}
# {'name': 'vercel/next.js', 'description': 'The React Framework', 'stars': 124937, 'language': 'JavaScript', 'forks': 26681, 'url': 'https://github.com/vercel/next.js', 'created_at': datetime.datetime(2016, 10, 5, 23, 32, 51, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 48, 49, tzinfo=datetime.timezone.utc)}
# {'name': 'formio/react', 'description': 'JSON powered forms for React.js', 'stars': 305, 'language': 'TypeScript', 'forks': 267, 'url': 'https://github.com/formio/react', 'created_at': datetime.datetime(2015, 9, 23, 21, 51, 26, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 12, 3, 36, 38, tzinfo=datetime.timezone.utc)}
# {'name': 'xzlaptt/React', 'description': 'React学习', 'stars': 461, 'language': 'JavaScript', 'forks': 221, 'url': 'https://github.com/xzlaptt/React', 'created_at': datetime.datetime(2021, 1, 25, 7, 30, 48, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 2, 45, 39, tzinfo=datetime.timezone.utc)}
# {'name': 'facebook/react-native', 'description': 'A framework for building native applications using React', 'stars': 118186, 'language': 'C++', 'forks': 24216, 'url': 'https://github.com/facebook/react-native', 'created_at': datetime.datetime(2015, 1, 9, 18, 10, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 34, 15, tzinfo=datetime.timezone.utc)}
# {'name': 'ui-router/react', 'description': '🔼 UI-Router for React', 'stars': 515, 'language': 'TypeScript', 'forks': 127, 'url': 'https://github.com/ui-router/react', 'created_at': datetime.datetime(2016, 6, 20, 19, 14, 56, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 12, 3, 36, 43, tzinfo=datetime.timezone.utc)}
# {'name': 'ReactiveCocoa/ReactiveCocoa', 'description': 'Cocoa framework and Obj-C dynamism bindings for ReactiveSwift.', 'stars': 19928, 'language': 'Swift', 'forks': 3470, 'url': 'https://github.com/ReactiveCocoa/ReactiveCocoa', 'created_at': datetime.datetime(2012, 3, 2, 22, 11, 24, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 12, 5, 50, 10, tzinfo=datetime.timezone.utc)}
# {'name': 'facebook/create-react-app', 'description': 'Set up a modern web app by running one command.', 'stars': 102521, 'language': 'JavaScript', 'forks': 26783, 'url': 'https://github.com/facebook/create-react-app', 'created_at': datetime.datetime(2016, 7, 17, 14, 55, 11, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 22, 21, tzinfo=datetime.timezone.utc)}
# {'name': 'azat-co/react', 'description': 'Examples for the React Quickly book. ', 'stars': 253, 'language': 'JavaScript', 'forks': 136, 'url': 'https://github.com/azat-co/react', 'created_at': datetime.datetime(2015, 7, 18, 23, 58, 37, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 12, 3, 37, 51, tzinfo=datetime.timezone.utc)}
# {'name': 'omergulcicek/react', 'description': '🌀 React kütüphanesinin Türkçe çevirisi', 'stars': 526, 'language': 'HTML', 'forks': 94, 'url': 'https://github.com/omergulcicek/react', 'created_at': datetime.datetime(2017, 12, 27, 13, 29, 3, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 7, 56, tzinfo=datetime.timezone.utc)}
# {'name': 'remix-run/react-router', 'description': 'Declarative routing for React', 'stars': 52780, 'language': 'TypeScript', 'forks': 10221, 'url': 'https://github.com/remix-run/react-router', 'created_at': datetime.datetime(2014, 5, 16, 22, 22, 51, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 4, 19, 9, tzinfo=datetime.timezone.utc)}
# {'name': 'phosphor-icons/react', 'description': 'A flexible icon family for React', 'stars': 1083, 'language': 'TypeScript', 'forks': 57, 'url': 'https://github.com/phosphor-icons/react', 'created_at': datetime.datetime(2020, 7, 18, 7, 46, 50, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 1, 7, 47, tzinfo=datetime.timezone.utc)}
# {'name': 'werein/react', 'description': 'Extremely simple boilerplate, easiest you can find, for React application including all the necessary tools: Flow | React 16 | redux | babel 6 | webpack 3 | css-modules | jest | enzyme | express + optional: sass/scss', 'stars': 276, 'language': 'JavaScript', 'forks': 95, 'url': 'https://github.com/werein/react', 'created_at': datetime.datetime(2015, 11, 7, 20, 22, 23, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 20, 6, 34, 19, tzinfo=datetime.timezone.utc)}
# {'name': 'streamich/react-use', 'description': 'React Hooks — 👍', 'stars': 41542, 'language': 'TypeScript', 'forks': 3134, 'url': 'https://github.com/streamich/react-use', 'created_at': datetime.datetime(2018, 10, 27, 10, 16, 5, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 10, 19, tzinfo=datetime.timezone.utc)}
# {'name': 'enaqx/awesome-react', 'description': 'A collection of awesome things regarding React ecosystem', 'stars': 64579, 'language': None, 'forks': 7172, 'url': 'https://github.com/enaqx/awesome-react', 'created_at': datetime.datetime(2014, 8, 6, 5, 31, 44, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 5, 52, tzinfo=datetime.timezone.utc)}
# {'name': 'Internshala-Online-Trainings/React', 'description': None, 'stars': 157, 'language': 'JavaScript', 'forks': 95, 'url': 'https://github.com/Internshala-Online-Trainings/React', 'created_at': datetime.datetime(2020, 10, 29, 12, 2, 6, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 29, 8, 51, 50, tzinfo=datetime.timezone.utc)}
# {'name': 'dvdzkwsk/react-redux-starter-kit', 'description': 'Get started with React, Redux, and React-Router.', 'stars': 10288, 'language': 'JavaScript', 'forks': 2201, 'url': 'https://github.com/dvdzkwsk/react-redux-starter-kit', 'created_at': datetime.datetime(2015, 6, 24, 18, 38, 28, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 4, 9, 8, 46, tzinfo=datetime.timezone.utc)}
# {'name': 'reactjs/react.dev', 'description': 'The React documentation website', 'stars': 10979, 'language': 'TypeScript', 'forks': 7504, 'url': 'https://github.com/reactjs/react.dev', 'created_at': datetime.datetime(2017, 10, 6, 3, 16, 4, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 15, 35, 57, tzinfo=datetime.timezone.utc)}
# {'name': 'react-boilerplate/react-boilerplate', 'description': '🔥 A highly scalable, offline-first foundation with the best developer experience and a focus on performance and best practices.', 'stars': 29451, 'language': 'JavaScript', 'forks': 6128, 'url': 'https://github.com/react-boilerplate/react-boilerplate', 'created_at': datetime.datetime(2015, 2, 18, 14, 36, 32, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 4, 35, tzinfo=datetime.timezone.utc)}
# {'name': 'sudheerj/reactjs-interview-questions', 'description': 'List of top 500 ReactJS Interview Questions & Answers....Coding exercise questions are coming soon!!', 'stars': 39099, 'language': 'JavaScript', 'forks': 9274, 'url': 'https://github.com/sudheerj/reactjs-interview-questions', 'created_at': datetime.datetime(2018, 5, 31, 17, 17, 1, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 13, 3, tzinfo=datetime.timezone.utc)}
# {'name': 'P5-wrapper/react', 'description': 'A wrapper component that allows you to utilise P5 sketches within React apps.', 'stars': 484, 'language': 'TypeScript', 'forks': 50, 'url': 'https://github.com/P5-wrapper/react', 'created_at': datetime.datetime(2016, 12, 21, 16, 45, 58, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 15, 10, 11, tzinfo=datetime.timezone.utc)}
# {'name': 'ruanyf/react-demos', 'description': 'a collection of simple demos of React.js', 'stars': 16254, 'language': 'JavaScript', 'forks': 6356, 'url': 'https://github.com/ruanyf/react-demos', 'created_at': datetime.datetime(2015, 3, 23, 10, 50, 7, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 11, 2, 52, 34, tzinfo=datetime.timezone.utc)}
# {'name': 'reactiveui/ReactiveUI', 'description': 'An advanced, composable, functional reactive model-view-viewmodel framework for all .NET platforms that is inspired by functional reactive programming. ReactiveUI allows you to  abstract mutable state away from your user interfaces, express the idea around a feature in one readable place and improve the testability of your application.', 'stars': 8048, 'language': 'C#', 'forks': 1115, 'url': 'https://github.com/reactiveui/ReactiveUI', 'created_at': datetime.datetime(2010, 6, 11, 5, 24, 29, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 23, 43, 6, tzinfo=datetime.timezone.utc)}
# {'name': 'marmelab/react-admin', 'description': 'A frontend Framework for single-page applications on top of REST/GraphQL APIs, using TypeScript, React and Material Design', 'stars': 24777, 'language': 'TypeScript', 'forks': 5219, 'url': 'https://github.com/marmelab/react-admin', 'created_at': datetime.datetime(2016, 7, 13, 7, 58, 54, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 22, 8, tzinfo=datetime.timezone.utc)}
# {'name': 'react-navigation/react-navigation', 'description': 'Routing and navigation for your React Native apps', 'stars': 23470, 'language': 'TypeScript', 'forks': 5012, 'url': 'https://github.com/react-navigation/react-navigation', 'created_at': datetime.datetime(2017, 1, 26, 19, 51, 40, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 11, 4, tzinfo=datetime.timezone.utc)}
# {'name': 'leilihuang/React', 'description': '写写React组件', 'stars': 149, 'language': 'JavaScript', 'forks': 68, 'url': 'https://github.com/leilihuang/React', 'created_at': datetime.datetime(2016, 6, 28, 9, 25, 7, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 7, 8, 8, 37, 16, tzinfo=datetime.timezone.utc)}
# {'name': 'JedWatson/react-select', 'description': 'The Select Component for React.js', 'stars': 27534, 'language': 'TypeScript', 'forks': 4118, 'url': 'https://github.com/JedWatson/react-select', 'created_at': datetime.datetime(2014, 8, 26, 4, 27, 45, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 13, 52, 37, tzinfo=datetime.timezone.utc)}
# {'name': 'kdchang/reactjs101', 'description': '從零開始學 ReactJS（ReactJS 101）是一本希望讓初學者一看就懂的 React 中文入門教學書，由淺入深學習 ReactJS 生態系 (Flux, Redux, React Router, ImmutableJS, React Native, Relay/GraphQL etc.)。', 'stars': 4299, 'language': 'JavaScript', 'forks': 1216, 'url': 'https://github.com/kdchang/reactjs101', 'created_at': datetime.datetime(2016, 3, 6, 4, 33, 40, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 11, 5, 26, 50, tzinfo=datetime.timezone.utc)}
# {'name': 'akiran/react-slick', 'description': 'React carousel component ', 'stars': 11718, 'language': 'JavaScript', 'forks': 2101, 'url': 'https://github.com/akiran/react-slick', 'created_at': datetime.datetime(2014, 11, 16, 5, 14, 39, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 9, 23, 9, tzinfo=datetime.timezone.utc)}
# {'name': 'software-mansion/react-native-svg', 'description': 'SVG library for React Native, React Native Web, and plain React web projects.', 'stars': 7427, 'language': 'Java', 'forks': 1119, 'url': 'https://github.com/software-mansion/react-native-svg', 'created_at': datetime.datetime(2016, 1, 17, 14, 29, 21, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 23, 2, 57, tzinfo=datetime.timezone.utc)}
# {'name': 'react-bootstrap/react-bootstrap', 'description': 'Bootstrap components built with React', 'stars': 22353, 'language': 'TypeScript', 'forks': 3586, 'url': 'https://github.com/react-bootstrap/react-bootstrap', 'created_at': datetime.datetime(2013, 12, 27, 19, 6, 7, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 15, 6, 21, tzinfo=datetime.timezone.utc)}
# {'name': 'reduxjs/react-redux', 'description': 'Official React bindings for Redux', 'stars': 23347, 'language': 'TypeScript', 'forks': 3376, 'url': 'https://github.com/reduxjs/react-redux', 'created_at': datetime.datetime(2015, 7, 11, 17, 32, 1, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 13, 43, 2, tzinfo=datetime.timezone.utc)}
# {'name': 'bvaughn/react-virtualized', 'description': 'React components for efficiently rendering large lists and tabular data', 'stars': 26268, 'language': 'JavaScript', 'forks': 3056, 'url': 'https://github.com/bvaughn/react-virtualized', 'created_at': datetime.datetime(2015, 11, 3, 0, 48, 7, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 13, 51, tzinfo=datetime.timezone.utc)}
# {'name': 'react-hook-form/react-hook-form', 'description': '📋 React Hooks for form state management and validation (Web + React Native)', 'stars': 41046, 'language': 'TypeScript', 'forks': 2049, 'url': 'https://github.com/react-hook-form/react-hook-form', 'created_at': datetime.datetime(2019, 3, 5, 23, 47, 10, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 43, 47, tzinfo=datetime.timezone.utc)}
# {'name': 'react-native-elements/react-native-elements', 'description': 'Cross-Platform React Native UI Toolkit', 'stars': 24942, 'language': 'MDX', 'forks': 4637, 'url': 'https://github.com/react-native-elements/react-native-elements', 'created_at': datetime.datetime(2016, 9, 8, 14, 21, 41, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 12, 57, 9, tzinfo=datetime.timezone.utc)}
# {'name': 'jondot/awesome-react-native', 'description': 'Awesome React Native components, news, tools, and learning material!', 'stars': 34507, 'language': 'JavaScript', 'forks': 3976, 'url': 'https://github.com/jondot/awesome-react-native', 'created_at': datetime.datetime(2015, 3, 26, 19, 58, 6, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 15, 47, 14, tzinfo=datetime.timezone.utc)}
# {'name': 'brillout/awesome-react-components', 'description': 'Curated List of React Components & Libraries.', 'stars': 41978, 'language': None, 'forks': 3462, 'url': 'https://github.com/brillout/awesome-react-components', 'created_at': datetime.datetime(2016, 6, 24, 15, 19, 33, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 7, 5, tzinfo=datetime.timezone.utc)}
# {'name': 'academind/react-complete-guide-code', 'description': 'Code snapshots and materials for our "React - The Complete Guide" course (https://acad.link/reactjs)', 'stars': 6299, 'language': None, 'forks': 12862, 'url': 'https://github.com/academind/react-complete-guide-code', 'created_at': datetime.datetime(2021, 3, 23, 15, 53, 9, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 12, 21, 29, tzinfo=datetime.timezone.utc)}
# {'name': 'reactioncommerce/reaction', 'description': 'Mailchimp Open Commerce is an API-first, headless commerce platform built using Node.js, React, GraphQL. Deployed via Docker and Kubernetes. ', 'stars': 12300, 'language': 'JavaScript', 'forks': 2167, 'url': 'https://github.com/reactioncommerce/reaction', 'created_at': datetime.datetime(2013, 9, 18, 15, 30, 36, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 59, 12, tzinfo=datetime.timezone.utc)}
# {'name': 'Asabeneh/30-Days-Of-React', 'description': '30 Days of  React challenge is a step by step guide to learn React in 30 days.  These videos may help too: https://www.youtube.com/channel/UC7PNRuno1rzYPb1xLa4yktw', 'stars': 25339, 'language': 'JavaScript', 'forks': 7212, 'url': 'https://github.com/Asabeneh/30-Days-Of-React', 'created_at': datetime.datetime(2020, 9, 29, 13, 38, 54, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 30, 19, tzinfo=datetime.timezone.utc)}
# {'name': 'alan2207/bulletproof-react', 'description': '🛡️ ⚛️ A simple, scalable, and powerful architecture for building production ready React applications. ', 'stars': 27072, 'language': 'TypeScript', 'forks': 2476, 'url': 'https://github.com/alan2207/bulletproof-react', 'created_at': datetime.datetime(2021, 5, 30, 14, 47, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 46, 28, tzinfo=datetime.timezone.utc)}
# {'name': 'ant-design/ant-design', 'description': 'An enterprise-class UI design language and React UI library', 'stars': 91893, 'language': 'TypeScript', 'forks': 48820, 'url': 'https://github.com/ant-design/ant-design', 'created_at': datetime.datetime(2015, 4, 24, 15, 37, 24, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 13, tzinfo=datetime.timezone.utc)}
# {'name': 'react-native-maps/react-native-maps', 'description': 'React Native Mapview component for iOS + Android', 'stars': 15041, 'language': 'Objective-C', 'forks': 4849, 'url': 'https://github.com/react-native-maps/react-native-maps', 'created_at': datetime.datetime(2015, 12, 29, 19, 54, 20, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 49, 9, tzinfo=datetime.timezone.utc)}
# {'name': 'kriasoft/react-starter-kit', 'description': "The web's most popular Jamstack front-end template (boilerplate) for building web applications with React", 'stars': 22662, 'language': 'TypeScript', 'forks': 4158, 'url': 'https://github.com/kriasoft/react-starter-kit', 'created_at': datetime.datetime(2014, 4, 16, 13, 8, 18, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 13, 2, 16, tzinfo=datetime.timezone.utc)}
# {'name': 'AmruthPillai/Reactive-Resume', 'description': 'A one-of-a-kind resume builder that keeps your privacy in mind. Completely secure, customizable, portable, open-source and free forever. Try it out today!', 'stars': 22693, 'language': 'TypeScript', 'forks': 2388, 'url': 'https://github.com/AmruthPillai/Reactive-Resume', 'created_at': datetime.datetime(2020, 3, 25, 14, 8, 22, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 40, 13, tzinfo=datetime.timezone.utc)}
# {'name': 'electron-react-boilerplate/electron-react-boilerplate', 'description': 'A Foundation for Scalable Cross-Platform Apps', 'stars': 23120, 'language': 'TypeScript', 'forks': 3850, 'url': 'https://github.com/electron-react-boilerplate/electron-react-boilerplate', 'created_at': datetime.datetime(2015, 5, 18, 9, 54, 57, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 10, 29, 58, tzinfo=datetime.timezone.utc)}
# {'name': 'wesbos/React-For-Beginners-Starter-Files', 'description': 'Starter files for learning React.js with React for Beginners', 'stars': 2883, 'language': 'JavaScript', 'forks': 2554, 'url': 'https://github.com/wesbos/React-For-Beginners-Starter-Files', 'created_at': datetime.datetime(2015, 10, 30, 19, 55, 52, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 0, 14, 34, tzinfo=datetime.timezone.utc)}
# {'name': 'reactos/reactos', 'description': 'A free Windows-compatible Operating System', 'stars': 14422, 'language': 'C', 'forks': 1730, 'url': 'https://github.com/reactos/reactos', 'created_at': datetime.datetime(2017, 10, 3, 8, 4, 52, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 28, 13, tzinfo=datetime.timezone.utc)}
# {'name': 'reactnativecn/react-native-guide', 'description': 'React Native指南汇集了各类react-native学习资源、开源App和组件', 'stars': 17591, 'language': None, 'forks': 3775, 'url': 'https://github.com/reactnativecn/react-native-guide', 'created_at': datetime.datetime(2015, 4, 10, 3, 34, 17, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 13, 24, 34, tzinfo=datetime.timezone.utc)}
# {'name': 'yisainan/react', 'description': '⚛ 比较好的react项目,值得借鉴与学习', 'stars': 182, 'language': 'JavaScript', 'forks': 42, 'url': 'https://github.com/yisainan/react', 'created_at': datetime.datetime(2018, 5, 7, 15, 25, 28, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 10, 14, 37, 6, tzinfo=datetime.timezone.utc)}
# {'name': 'coryhouse/react-slingshot', 'description': 'React + Redux starter kit / boilerplate with Babel, hot reloading, testing, linting and a working example app built in', 'stars': 9745, 'language': 'JavaScript', 'forks': 2946, 'url': 'https://github.com/coryhouse/react-slingshot', 'created_at': datetime.datetime(2015, 12, 31, 22, 4, 53, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 22, 4, 54, tzinfo=datetime.timezone.utc)}
# {'name': 'StephenGrider/ReactNativeReduxCasts', 'description': 'Companion Repo for The Complete React Native and Redux Course', 'stars': 2567, 'language': 'JavaScript', 'forks': 1301, 'url': 'https://github.com/StephenGrider/ReactNativeReduxCasts', 'created_at': datetime.datetime(2016, 9, 19, 16, 57, 30, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 10, 15, 1, 49, tzinfo=datetime.timezone.utc)}
# {'name': 'Semantic-Org/Semantic-UI-React', 'description': 'The official Semantic-UI-React integration', 'stars': 13209, 'language': 'JavaScript', 'forks': 4051, 'url': 'https://github.com/Semantic-Org/Semantic-UI-React', 'created_at': datetime.datetime(2015, 6, 19, 16, 47, 19, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 16, 48, 32, tzinfo=datetime.timezone.utc)}
# {'name': 'react-dnd/react-dnd', 'description': 'Drag and Drop for React', 'stars': 20899, 'language': 'TypeScript', 'forks': 1989, 'url': 'https://github.com/react-dnd/react-dnd', 'created_at': datetime.datetime(2014, 10, 19, 13, 29, 28, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 15, 54, 43, tzinfo=datetime.timezone.utc)}
# {'name': 'john-smilga/react-projects', 'description': None, 'stars': 4825, 'language': 'CSS', 'forks': 3873, 'url': 'https://github.com/john-smilga/react-projects', 'created_at': datetime.datetime(2020, 9, 27, 20, 45, 5, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 53, 31, tzinfo=datetime.timezone.utc)}
# {'name': 'tsparticles/react', 'description': 'React tsParticles official component', 'stars': 396, 'language': 'JavaScript', 'forks': 28, 'url': 'https://github.com/tsparticles/react', 'created_at': datetime.datetime(2022, 11, 11, 0, 27, 50, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 17, 36, 26, tzinfo=datetime.timezone.utc)}
# {'name': 'alpersonalwebsite/react', 'description': 'React[0] + Redux[0] > A brief introduction to React and Redux', 'stars': 172, 'language': None, 'forks': 39, 'url': 'https://github.com/alpersonalwebsite/react', 'created_at': datetime.datetime(2018, 6, 25, 20, 46, 15, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 3, 16, 15, 54, 1, tzinfo=datetime.timezone.utc)}
# {'name': 'atlassian/react-beautiful-dnd', 'description': 'Beautiful and accessible drag and drop for lists with React', 'stars': 33158, 'language': 'JavaScript', 'forks': 2529, 'url': 'https://github.com/atlassian/react-beautiful-dnd', 'created_at': datetime.datetime(2017, 8, 9, 3, 37, 15, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 17, 45, 43, tzinfo=datetime.timezone.utc)}
# {'name': 'epicweb-dev/react-fundamentals', 'description': 'Material for my React Fundamentals Workshop', 'stars': 5263, 'language': 'TypeScript', 'forks': 3184, 'url': 'https://github.com/epicweb-dev/react-fundamentals', 'created_at': datetime.datetime(2019, 5, 31, 19, 40, 49, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 7, 33, 24, tzinfo=datetime.timezone.utc)}
# {'name': 'react-grid-layout/react-draggable', 'description': 'React draggable component', 'stars': 8982, 'language': 'JavaScript', 'forks': 1025, 'url': 'https://github.com/react-grid-layout/react-draggable', 'created_at': datetime.datetime(2014, 7, 24, 22, 32, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 21, 57, 56, tzinfo=datetime.timezone.utc)}
# {'name': 'bailicangdu/react-pxq', 'description': '一个 react + redux 的完整项目 和 个人总结', 'stars': 7515, 'language': 'JavaScript', 'forks': 2156, 'url': 'https://github.com/bailicangdu/react-pxq', 'created_at': datetime.datetime(2016, 11, 7, 3, 30, 29, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 5, 50, 22, tzinfo=datetime.timezone.utc)}
# {'name': 'markerikson/react-redux-links', 'description': "Curated tutorial and resource links I've collected on React, Redux, ES6, and more", 'stars': 22579, 'language': None, 'forks': 2504, 'url': 'https://github.com/markerikson/react-redux-links', 'created_at': datetime.datetime(2016, 1, 22, 2, 10, 28, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 12, 52, 34, tzinfo=datetime.timezone.utc)}
# {'name': 'RocketChat/Rocket.Chat.ReactNative', 'description': 'Rocket.Chat mobile clients', 'stars': 1983, 'language': 'TypeScript', 'forks': 1158, 'url': 'https://github.com/RocketChat/Rocket.Chat.ReactNative', 'created_at': datetime.datetime(2017, 8, 3, 18, 21, 33, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 20, 40, 40, tzinfo=datetime.timezone.utc)}
# {'name': 'react-grid-layout/react-grid-layout', 'description': 'A draggable and resizable grid layout with responsive breakpoints, for React.', 'stars': 20219, 'language': 'JavaScript', 'forks': 2567, 'url': 'https://github.com/react-grid-layout/react-grid-layout', 'created_at': datetime.datetime(2014, 12, 27, 14, 28, 40, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 13, 29, 43, tzinfo=datetime.timezone.utc)}
# {'name': 'react-native-camera/react-native-camera', 'description': 'A Camera component for React Native. Also supports barcode scanning!', 'stars': 9632, 'language': 'Java', 'forks': 3513, 'url': 'https://github.com/react-native-camera/react-native-camera', 'created_at': datetime.datetime(2015, 4, 1, 0, 54, 40, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 23, 43, 18, tzinfo=datetime.timezone.utc)}
# {'name': 'reactstrap/reactstrap', 'description': 'Simple React Bootstrap 5 components', 'stars': 10589, 'language': 'JavaScript', 'forks': 1297, 'url': 'https://github.com/reactstrap/reactstrap', 'created_at': datetime.datetime(2016, 2, 19, 8, 1, 36, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 10, 40, tzinfo=datetime.timezone.utc)}
# {'name': 'react-component/slider', 'description': 'React Slider', 'stars': 3034, 'language': 'TypeScript', 'forks': 769, 'url': 'https://github.com/react-component/slider', 'created_at': datetime.datetime(2015, 4, 19, 7, 30, 44, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 2, 24, 58, tzinfo=datetime.timezone.utc)}
# {'name': 'reactGo/reactGo', 'description': 'Your One-Stop solution for a full-stack universal Redux App!', 'stars': 2805, 'language': 'TypeScript', 'forks': 563, 'url': 'https://github.com/reactGo/reactGo', 'created_at': datetime.datetime(2014, 11, 17, 9, 51, 9, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 12, 19, 15, 21, tzinfo=datetime.timezone.utc)}
# {'name': 'enzymejs/enzyme', 'description': 'JavaScript Testing utilities for React', 'stars': 19957, 'language': 'JavaScript', 'forks': 2013, 'url': 'https://github.com/enzymejs/enzyme', 'created_at': datetime.datetime(2015, 11, 10, 21, 45, 38, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 14, 33, 57, tzinfo=datetime.timezone.utc)}
# {'name': 'Hacker0x01/react-datepicker', 'description': 'A simple and reusable datepicker component for React', 'stars': 7958, 'language': 'TypeScript', 'forks': 2231, 'url': 'https://github.com/Hacker0x01/react-datepicker', 'created_at': datetime.datetime(2014, 6, 22, 7, 40, 48, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 6, 44, 6, tzinfo=datetime.timezone.utc)}
# {'name': 'benoitvallon/react-native-nw-react-calculator', 'description': 'Mobile, desktop and website Apps with the same code', 'stars': 5208, 'language': 'JavaScript', 'forks': 865, 'url': 'https://github.com/benoitvallon/react-native-nw-react-calculator', 'created_at': datetime.datetime(2015, 5, 1, 19, 45, 38, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 0, 3, 37, tzinfo=datetime.timezone.utc)}
# {'name': 'react-dates/react-dates', 'description': 'An easily internationalizable, mobile-friendly datepicker library for the web', 'stars': 12213, 'language': 'JavaScript', 'forks': 1709, 'url': 'https://github.com/react-dates/react-dates', 'created_at': datetime.datetime(2016, 5, 4, 0, 49, 45, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 19, 12, 57, tzinfo=datetime.timezone.utc)}
# {'name': 'chvin/react-tetris', 'description': 'Use React, Redux, Immutable to code Tetris. 🎮', 'stars': 8289, 'language': 'JavaScript', 'forks': 2110, 'url': 'https://github.com/chvin/react-tetris', 'created_at': datetime.datetime(2016, 12, 20, 12, 26, 11, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 14, 46, 17, tzinfo=datetime.timezone.utc)}
# {'name': 'wix/react-native-navigation', 'description': 'A complete native navigation solution for React Native', 'stars': 13030, 'language': 'MDX', 'forks': 2671, 'url': 'https://github.com/wix/react-native-navigation', 'created_at': datetime.datetime(2016, 3, 11, 11, 22, 54, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 5, 29, 52, tzinfo=datetime.timezone.utc)}
# {'name': 'facebook/react-devtools', 'description': 'An extension that allows inspection of React component hierarchy in the Chrome and Firefox Developer Tools.', 'stars': 11037, 'language': None, 'forks': 1783, 'url': 'https://github.com/facebook/react-devtools', 'created_at': datetime.datetime(2013, 9, 4, 20, 28, 43, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 12, 53, 41, tzinfo=datetime.timezone.utc)}
# {'name': 'pmndrs/react-spring', 'description': '✌️ A spring physics based React animation library', 'stars': 27984, 'language': 'TypeScript', 'forks': 1189, 'url': 'https://github.com/pmndrs/react-spring', 'created_at': datetime.datetime(2018, 3, 7, 15, 39, 32, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 7, 29, tzinfo=datetime.timezone.utc)}
# {'name': 'rehooks/awesome-react-hooks', 'description': 'Awesome React Hooks', 'stars': 9812, 'language': None, 'forks': 780, 'url': 'https://github.com/rehooks/awesome-react-hooks', 'created_at': datetime.datetime(2018, 10, 25, 21, 31, 44, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 23, 45, 58, tzinfo=datetime.timezone.utc)}
# {'name': 'necolas/react-native-web', 'description': 'Cross-platform React UI packages', 'stars': 21583, 'language': 'JavaScript', 'forks': 1780, 'url': 'https://github.com/necolas/react-native-web', 'created_at': datetime.datetime(2015, 6, 9, 19, 25, 38, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 2, 45, 57, tzinfo=datetime.timezone.utc)}
# {'name': 'react-native-webview/react-native-webview', 'description': 'React Native Cross-Platform WebView', 'stars': 6468, 'language': 'TypeScript', 'forks': 2986, 'url': 'https://github.com/react-native-webview/react-native-webview', 'created_at': datetime.datetime(2018, 9, 9, 0, 14, 44, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 14, 8, 17, tzinfo=datetime.timezone.utc)}
# {'name': 'infinitered/reactotron', 'description': 'A desktop app for inspecting your React JS and React Native projects. macOS, Linux, and Windows.', 'stars': 14824, 'language': 'TypeScript', 'forks': 942, 'url': 'https://github.com/infinitered/reactotron', 'created_at': datetime.datetime(2016, 4, 15, 21, 58, 32, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 14, 57, 17, tzinfo=datetime.timezone.utc)}
# {'name': 'wix/react-native-calendars', 'description': 'React Native Calendar Components 🗓️ 📆 ', 'stars': 9458, 'language': 'TypeScript', 'forks': 2930, 'url': 'https://github.com/wix/react-native-calendars', 'created_at': datetime.datetime(2016, 11, 11, 12, 17, 27, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 10, 20, 7, tzinfo=datetime.timezone.utc)}
# {'name': 'adam-golab/react-developer-roadmap', 'description': 'Roadmap to becoming a React developer', 'stars': 18820, 'language': 'JavaScript', 'forks': 2033, 'url': 'https://github.com/adam-golab/react-developer-roadmap', 'created_at': datetime.datetime(2018, 6, 16, 13, 40, 50, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 17, 23, 8, tzinfo=datetime.timezone.utc)}
# {'name': 'chenglou/react-motion', 'description': 'A spring that solves your animation problems.', 'stars': 21679, 'language': 'JavaScript', 'forks': 1160, 'url': 'https://github.com/chenglou/react-motion', 'created_at': datetime.datetime(2015, 6, 11, 7, 38, 23, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 11, 26, 51, tzinfo=datetime.timezone.utc)}
# {'name': 'yezihaohao/react-admin', 'description': ':sparkles: react-admin system solution : react 后台管理系统解决方案', 'stars': 6639, 'language': 'TypeScript', 'forks': 1871, 'url': 'https://github.com/yezihaohao/react-admin', 'created_at': datetime.datetime(2017, 4, 12, 2, 50, 56, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 9, 40, tzinfo=datetime.timezone.utc)}
# {'name': 'jsx-eslint/eslint-plugin-react', 'description': 'React-specific linting rules for ESLint', 'stars': 8933, 'language': 'JavaScript', 'forks': 2769, 'url': 'https://github.com/jsx-eslint/eslint-plugin-react', 'created_at': datetime.datetime(2014, 12, 15, 23, 44, 14, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 8, 10, 4, tzinfo=datetime.timezone.utc)}
# {'name': 'booleanhunter/ReactJS-AdminLTE', 'description': 'ReactJS version of the original AdminLTE dashboard (EXPERIMENTAL)- https://github.com/almasaeed2010/AdminLTE', 'stars': 2347, 'language': 'JavaScript', 'forks': 801, 'url': 'https://github.com/booleanhunter/ReactJS-AdminLTE', 'created_at': datetime.datetime(2015, 9, 30, 4, 4, 35, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 12, 3, 38, 29, tzinfo=datetime.timezone.utc)}
# {'name': 'rjsf-team/react-jsonschema-form', 'description': 'A React component for building Web forms from JSON Schema.', 'stars': 14112, 'language': 'TypeScript', 'forks': 2177, 'url': 'https://github.com/rjsf-team/react-jsonschema-form', 'created_at': datetime.datetime(2015, 12, 16, 15, 14, 5, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 10, 10, 18, tzinfo=datetime.timezone.utc)}
# {'name': 'lottie-react-native/lottie-react-native', 'description': 'Lottie wrapper for React Native.', 'stars': 16670, 'language': 'Kotlin', 'forks': 1771, 'url': 'https://github.com/lottie-react-native/lottie-react-native', 'created_at': datetime.datetime(2017, 1, 27, 18, 24, 50, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 23, 43, 48, tzinfo=datetime.timezone.utc)}
# {'name': 'FaridSafi/react-native-gifted-chat', 'description': '💬 The most complete chat UI for React Native', 'stars': 13450, 'language': 'TypeScript', 'forks': 3540, 'url': 'https://github.com/FaridSafi/react-native-gifted-chat', 'created_at': datetime.datetime(2015, 11, 14, 15, 45, 34, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 0, 17, 44, tzinfo=datetime.timezone.utc)}
# {'name': 'TheWidlarzGroup/react-native-video', 'description': 'A <Video /> component for react-native', 'stars': 7142, 'language': 'Swift', 'forks': 2878, 'url': 'https://github.com/TheWidlarzGroup/react-native-video', 'created_at': datetime.datetime(2015, 3, 31, 5, 8, 38, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 18, 22, 18, tzinfo=datetime.timezone.utc)}
# {'name': 'creativetimofficial/material-dashboard-react', 'description': 'React version of Material Dashboard by Creative Tim', 'stars': 2820, 'language': 'JavaScript', 'forks': 4144, 'url': 'https://github.com/creativetimofficial/material-dashboard-react', 'created_at': datetime.datetime(2017, 12, 12, 13, 59, 20, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 3, 18, 14, tzinfo=datetime.timezone.utc)}
# {'name': 'wesbos/Advanced-React', 'description': 'Starter Files and Solutions for Full Stack Advanced React and GraphQL ', 'stars': 3537, 'language': 'JavaScript', 'forks': 2429, 'url': 'https://github.com/wesbos/Advanced-React', 'created_at': datetime.datetime(2017, 8, 9, 2, 8, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 16, 24, 10, tzinfo=datetime.timezone.utc)}
# {'name': 'invertase/react-native-firebase', 'description': '🔥 A well-tested feature-rich modular Firebase implementation for React Native. Supports both iOS & Android platforms for all Firebase services.', 'stars': 11632, 'language': 'JavaScript', 'forks': 2202, 'url': 'https://github.com/invertase/react-native-firebase', 'created_at': datetime.datetime(2017, 2, 1, 12, 1, 3, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 10, 47, 48, tzinfo=datetime.timezone.utc)}
# {'name': 'pmndrs/react-three-fiber', 'description': '🇨🇭 A React renderer for Three.js', 'stars': 27127, 'language': 'TypeScript', 'forks': 1546, 'url': 'https://github.com/pmndrs/react-three-fiber', 'created_at': datetime.datetime(2019, 2, 25, 14, 31, 51, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 9, 25, tzinfo=datetime.timezone.utc)}
# {'name': 'styleguidist/react-styleguidist', 'description': 'Isolated React component development environment with a living style guide', 'stars': 10827, 'language': 'TypeScript', 'forks': 1436, 'url': 'https://github.com/styleguidist/react-styleguidist', 'created_at': datetime.datetime(2015, 9, 7, 5, 30, 30, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 9, 7, 59, tzinfo=datetime.timezone.utc)}
# {'name': 'leecade/react-native-swiper', 'description': 'The best Swiper component for React Native.', 'stars': 10403, 'language': 'JavaScript', 'forks': 2337, 'url': 'https://github.com/leecade/react-native-swiper', 'created_at': datetime.datetime(2015, 4, 20, 15, 22, 55, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 14, 6, 17, tzinfo=datetime.timezone.utc)}
# {'name': 'ReactiveCocoa/ReactiveSwift', 'description': 'Streams of values over time', 'stars': 3002, 'language': 'Swift', 'forks': 430, 'url': 'https://github.com/ReactiveCocoa/ReactiveSwift', 'created_at': datetime.datetime(2016, 5, 21, 16, 20, 3, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 10, 22, 19, 13, tzinfo=datetime.timezone.utc)}
# {'name': 'Bogdan-Lyashenko/Under-the-hood-ReactJS', 'description': 'Entire React code base explanation by visual block schemes (Stack version) ', 'stars': 6477, 'language': 'JavaScript', 'forks': 594, 'url': 'https://github.com/Bogdan-Lyashenko/Under-the-hood-ReactJS', 'created_at': datetime.datetime(2017, 6, 22, 20, 46, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 13, 20, 10, 27, tzinfo=datetime.timezone.utc)}
# {'name': 'callstack/react-native-paper', 'description': 'Material Design for React Native (Android & iOS)', 'stars': 12736, 'language': 'TypeScript', 'forks': 2075, 'url': 'https://github.com/callstack/react-native-paper', 'created_at': datetime.datetime(2016, 10, 19, 5, 56, 53, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 15, 15, 16, tzinfo=datetime.timezone.utc)}
# {'name': 'learn-anything/learn-anything', 'description': "Organize world's knowledge, explore connections and curate learning paths", 'stars': 15971, 'language': 'TypeScript', 'forks': 973, 'url': 'https://github.com/learn-anything/learn-anything', 'created_at': datetime.datetime(2016, 8, 8, 16, 9, 17, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 23, 43, 41, tzinfo=datetime.timezone.utc)}
# {'name': 'acdlite/react-fiber-architecture', 'description': "A description of React's new core algorithm, React Fiber", 'stars': 11605, 'language': None, 'forks': 590, 'url': 'https://github.com/acdlite/react-fiber-architecture', 'created_at': datetime.datetime(2016, 7, 19, 1, 15, 34, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 16, 57, 44, tzinfo=datetime.timezone.utc)}
# {'name': 'diegomura/react-pdf', 'description': '📄  Create PDF files using React', 'stars': 14660, 'language': 'JavaScript', 'forks': 1163, 'url': 'https://github.com/diegomura/react-pdf', 'created_at': datetime.datetime(2016, 10, 18, 21, 33, 58, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 11, 33, 19, tzinfo=datetime.timezone.utc)}
# {'name': 'vercel/swr', 'description': 'React Hooks for Data Fetching', 'stars': 30244, 'language': 'TypeScript', 'forks': 1210, 'url': 'https://github.com/vercel/swr', 'created_at': datetime.datetime(2019, 10, 28, 18, 16, 1, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 23, 15, 26, tzinfo=datetime.timezone.utc)}
# {'name': 'vasanthk/react-bits', 'description': '✨ React patterns, techniques, tips and tricks ✨', 'stars': 16827, 'language': None, 'forks': 1086, 'url': 'https://github.com/vasanthk/react-bits', 'created_at': datetime.datetime(2016, 12, 20, 6, 49, 54, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 11, 25, 52, tzinfo=datetime.timezone.utc)}
# {'name': 'erikras/react-redux-universal-hot-example', 'description': 'A starter boilerplate for a universal webapp using express, react, redux, webpack, and react-transform', 'stars': 12001, 'language': 'JavaScript', 'forks': 2499, 'url': 'https://github.com/erikras/react-redux-universal-hot-example', 'created_at': datetime.datetime(2015, 6, 23, 16, 39, 21, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 7, 12, 49, 49, tzinfo=datetime.timezone.utc)}
# {'name': 'facebook/react-native-website', 'description': 'The React Native website and docs', 'stars': 1935, 'language': 'JavaScript', 'forks': 4355, 'url': 'https://github.com/facebook/react-native-website', 'created_at': datetime.datetime(2017, 10, 31, 22, 34, 42, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 15, 15, 30, tzinfo=datetime.timezone.utc)}
# {'name': 'reactjs/react-tutorial', 'description': 'Code from the React tutorial.', 'stars': 3290, 'language': 'JavaScript', 'forks': 2133, 'url': 'https://github.com/reactjs/react-tutorial', 'created_at': datetime.datetime(2014, 6, 30, 4, 42, 12, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 19, 12, 4, 8, tzinfo=datetime.timezone.utc)}
# {'name': 'umijs/umi', 'description': 'A framework in react community ✨', 'stars': 15297, 'language': 'TypeScript', 'forks': 2652, 'url': 'https://github.com/umijs/umi', 'created_at': datetime.datetime(2017, 11, 22, 10, 9, 36, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 15, 15, 35, 38, tzinfo=datetime.timezone.utc)}
# {'name': 'remarkjs/react-markdown', 'description': 'Markdown component for React', 'stars': 12950, 'language': 'JavaScript', 'forks': 866, 'url': 'https://github.com/remarkjs/react-markdown', 'created_at': datetime.datetime(2015, 5, 18, 23, 59, 17, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 13, 1, 29, tzinfo=datetime.timezone.utc)}
# {'name': 'jquense/react-big-calendar', 'description': 'gcal/outlook like calendar component', 'stars': 7728, 'language': 'JavaScript', 'forks': 2221, 'url': 'https://github.com/jquense/react-big-calendar', 'created_at': datetime.datetime(2015, 8, 22, 2, 56, 58, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 16, 21, 11, tzinfo=datetime.timezone.utc)}
# {'name': 'reactchartjs/react-chartjs-2', 'description': 'React components for Chart.js, the most popular charting library', 'stars': 6561, 'language': 'TypeScript', 'forks': 2369, 'url': 'https://github.com/reactchartjs/react-chartjs-2', 'created_at': datetime.datetime(2016, 5, 6, 22, 1, 8, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 14, 22, 47, 48, tzinfo=datetime.timezone.utc)}
# ...
# {'name': 'angular/angular-hint', 'description': 'run-time hinting for AngularJS applications', 'stars': 362, 'language': 'JavaScript', 'forks': 45, 'url': 'https://github.com/angular/angular-hint', 'created_at': datetime.datetime(2014, 6, 23, 22, 46, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 5, 18, 19, 42, 53, tzinfo=datetime.timezone.utc)}
# {'name': 'bvaughn/angular-form-for', 'description': 'Set of Angular directives to simplify creating and validating HTML forms.', 'stars': 428, 'language': 'JavaScript', 'forks': 56, 'url': 'https://github.com/bvaughn/angular-form-for', 'created_at': datetime.datetime(2014, 7, 31, 5, 23, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 6, 13, 7, 12, 11, tzinfo=datetime.timezone.utc)}
# {'name': 'ultimatecourses/ngrx-store-effects-app', 'description': 'Project seed app for our NGRX application using Angular, NGRX Store, Effects, Router Store.', 'stars': 532, 'language': 'TypeScript', 'forks': 1172, 'url': 'https://github.com/ultimatecourses/ngrx-store-effects-app', 'created_at': datetime.datetime(2017, 11, 26, 15, 30, 3, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 3, 12, 36, 12, tzinfo=datetime.timezone.utc)}
# {'name': 'ncstate-sat/popover', 'description': 'Popover component for Angular', 'stars': 226, 'language': 'TypeScript', 'forks': 47, 'url': 'https://github.com/ncstate-sat/popover', 'created_at': datetime.datetime(2017, 9, 8, 20, 14, 30, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 7, 12, 19, 21, 25, tzinfo=datetime.timezone.utc)}
# {'name': 'serhiisol/ngx-auth', 'description': 'Angular 16+ Authentication Module', 'stars': 234, 'language': 'TypeScript', 'forks': 47, 'url': 'https://github.com/serhiisol/ngx-auth', 'created_at': datetime.datetime(2017, 2, 22, 21, 9, 44, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 7, 8, 0, 6, tzinfo=datetime.timezone.utc)}
# {'name': 'jettro/c3-angular-directive', 'description': 'Contains angularjs directives that use c3js to create good looking graphs', 'stars': 203, 'language': 'JavaScript', 'forks': 98, 'url': 'https://github.com/jettro/c3-angular-directive', 'created_at': datetime.datetime(2014, 7, 27, 12, 22, 59, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 4, 24, 11, 48, 55, tzinfo=datetime.timezone.utc)}
# {'name': 'gonewandering/angles', 'description': 'An angular.js wrapper for Chart.js', 'stars': 632, 'language': 'JavaScript', 'forks': 87, 'url': 'https://github.com/gonewandering/angles', 'created_at': datetime.datetime(2013, 7, 18, 1, 15, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 18, 7, 31, 6, tzinfo=datetime.timezone.utc)}
# {'name': 'strongloop/loopback-sdk-angular', 'description': 'Service for auto-generating Angular $resource services for LoopBack', 'stars': 155, 'language': 'JavaScript', 'forks': 83, 'url': 'https://github.com/strongloop/loopback-sdk-angular', 'created_at': datetime.datetime(2014, 1, 9, 6, 28, 10, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 4, 15, 20, 47, 29, tzinfo=datetime.timezone.utc)}
# {'name': 'stevepapa/angular2-autosize', 'description': 'angular2-autosize is an Angular2 directive that automatically adjusts textarea height to fit content.', 'stars': 118, 'language': 'TypeScript', 'forks': 29, 'url': 'https://github.com/stevepapa/angular2-autosize', 'created_at': datetime.datetime(2016, 2, 9, 8, 59, 43, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 1, 15, 5, 27, 38, tzinfo=datetime.timezone.utc)}
# {'name': 'single-spa/single-spa-angular', 'description': 'Helpers for building single-spa applications which use Angular', 'stars': 199, 'language': 'TypeScript', 'forks': 78, 'url': 'https://github.com/single-spa/single-spa-angular', 'created_at': datetime.datetime(2016, 11, 13, 4, 6, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 10, 17, 54, 3, tzinfo=datetime.timezone.utc)}
# {'name': 'pdanis/angular-puzzle', 'description': 'Sliding puzzle and word search puzzle powered by AngularJS', 'stars': 115, 'language': 'JavaScript', 'forks': 71, 'url': 'https://github.com/pdanis/angular-puzzle', 'created_at': datetime.datetime(2012, 6, 8, 21, 22, 22, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 12, 7, 15, 29, 35, tzinfo=datetime.timezone.utc)}
# {'name': 'mfauveau/angular-query-builder', 'description': 'Dynamic query building UI written in Angular.', 'stars': 218, 'language': 'HTML', 'forks': 72, 'url': 'https://github.com/mfauveau/angular-query-builder', 'created_at': datetime.datetime(2014, 7, 18, 2, 56, 1, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 7, 27, 14, 38, 35, tzinfo=datetime.timezone.utc)}
# {'name': 'cvqluu/Angular-Penalty-Softmax-Losses-Pytorch', 'description': 'Angular penalty loss functions in Pytorch (ArcFace, SphereFace, Additive Margin, CosFace) ', 'stars': 481, 'language': 'Python', 'forks': 92, 'url': 'https://github.com/cvqluu/Angular-Penalty-Softmax-Losses-Pytorch', 'created_at': datetime.datetime(2019, 6, 13, 17, 9, 43, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 29, 7, 6, 7, tzinfo=datetime.timezone.utc)}
# {'name': 'jeroenheijmans/sample-angular-oauth2-oidc-with-auth-guards', 'description': 'Basic example of how to integrate the angular-oauth2-oidc library in an Angular SPA utilizing AuthGuards.', 'stars': 256, 'language': 'TypeScript', 'forks': 113, 'url': 'https://github.com/jeroenheijmans/sample-angular-oauth2-oidc-with-auth-guards', 'created_at': datetime.datetime(2018, 6, 14, 21, 59, 14, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 6, 15, 34, 23, tzinfo=datetime.timezone.utc)}
# {'name': 'aitboudad/ngx-loading-bar', 'description': 'Automatic page loading / progress bar for Angular', 'stars': 760, 'language': 'TypeScript', 'forks': 81, 'url': 'https://github.com/aitboudad/ngx-loading-bar', 'created_at': datetime.datetime(2016, 12, 13, 10, 39, 39, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 22, 15, 8, 2, tzinfo=datetime.timezone.utc)}
# {'name': 'Azure-Samples/active-directory-angularjs-singlepageapp', 'description': 'An AngularJS based single page app, implemented with an ASP.NET Web API backend, that signs in users and calls web APIs using Azure AD', 'stars': 172, 'language': 'JavaScript', 'forks': 109, 'url': 'https://github.com/Azure-Samples/active-directory-angularjs-singlepageapp', 'created_at': datetime.datetime(2014, 10, 22, 6, 56, 38, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 29, 23, 2, 41, tzinfo=datetime.timezone.utc)}
# {'name': 'RenanRB/curso-angular', 'description': 'Curso desenvolvido para a plataforma https://digitalinnovation.one/', 'stars': 109, 'language': 'TypeScript', 'forks': 75, 'url': 'https://github.com/RenanRB/curso-angular', 'created_at': datetime.datetime(2019, 12, 30, 21, 8, 28, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 2, 27, 17, 3, 48, tzinfo=datetime.timezone.utc)}
# {'name': 'msfrisbie/egghead-angularjs', 'description': 'Functioning and annotated example code for each of the egghead.io AngularJS videos', 'stars': 193, 'language': 'JavaScript', 'forks': 58, 'url': 'https://github.com/msfrisbie/egghead-angularjs', 'created_at': datetime.datetime(2013, 6, 14, 0, 38, 1, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 12, 26, 18, 19, 53, tzinfo=datetime.timezone.utc)}
# {'name': 'saymedia/angularjs-server', 'description': 'Specialized server for AngularJS sites', 'stars': 248, 'language': 'JavaScript', 'forks': 49, 'url': 'https://github.com/saymedia/angularjs-server', 'created_at': datetime.datetime(2013, 9, 29, 0, 57, 36, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 11, 30, 10, 28, 50, tzinfo=datetime.timezone.utc)}
# {'name': 'marmelab/ng-admin', 'description': 'Add an AngularJS admin GUI to any RESTful API', 'stars': 3953, 'language': 'JavaScript', 'forks': 728, 'url': 'https://github.com/marmelab/ng-admin', 'created_at': datetime.datetime(2014, 5, 22, 12, 0, 10, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 25, 18, 41, 5, tzinfo=datetime.timezone.utc)}
# {'name': 'nickholub/angular-dashboard-app', 'description': 'Dashboard/Widgets functionality with AngularJS', 'stars': 202, 'language': 'CSS', 'forks': 73, 'url': 'https://github.com/nickholub/angular-dashboard-app', 'created_at': datetime.datetime(2014, 1, 6, 23, 32, 8, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 10, 8, 5, 57, 23, tzinfo=datetime.timezone.utc)}
# {'name': 'LukasMarx/angular-file-upload', 'description': None, 'stars': 136, 'language': 'TypeScript', 'forks': 88, 'url': 'https://github.com/LukasMarx/angular-file-upload', 'created_at': datetime.datetime(2018, 8, 8, 6, 57, 4, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 9, 27, 6, 26, 38, tzinfo=datetime.timezone.utc)}
# {'name': 'alvarotrigo/angular-fullpage', 'description': 'Official Angular wrapper for fullPage.js https://alvarotrigo.com/angular-fullpage/', 'stars': 175, 'language': 'TypeScript', 'forks': 45, 'url': 'https://github.com/alvarotrigo/angular-fullpage', 'created_at': datetime.datetime(2018, 10, 8, 22, 44, 14, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 6, 12, 48, 49, tzinfo=datetime.timezone.utc)}
# {'name': 'sugarac/angular-online-judge', 'description': 'A mini LeetCode with the collaborative feature.', 'stars': 195, 'language': 'TypeScript', 'forks': 76, 'url': 'https://github.com/sugarac/angular-online-judge', 'created_at': datetime.datetime(2017, 12, 23, 20, 13, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2022, 12, 16, 7, 39, tzinfo=datetime.timezone.utc)}
# {'name': 'cornflourblue/angular-6-jwt-authentication-example', 'description': 'Angular 6 JWT Authentication Example', 'stars': 124, 'language': 'TypeScript', 'forks': 83, 'url': 'https://github.com/cornflourblue/angular-6-jwt-authentication-example', 'created_at': datetime.datetime(2018, 5, 21, 21, 58, 16, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 1, 12, 13, 8, 53, tzinfo=datetime.timezone.utc)}
# {'name': 'vladotesanovic/ngSemantic', 'description': 'Angular 2 building blocks :package: based on Semantic UI', 'stars': 973, 'language': 'TypeScript', 'forks': 148, 'url': 'https://github.com/vladotesanovic/ngSemantic', 'created_at': datetime.datetime(2015, 9, 27, 17, 23, 4, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 6, 23, 4, 53, 28, tzinfo=datetime.timezone.utc)}
# {'name': 'colthreepv/angular-media-player', 'description': 'AngularJS Directive that wraps <audio> or <video> tag exposing methods and properties to manipulate your player', 'stars': 228, 'language': 'JavaScript', 'forks': 71, 'url': 'https://github.com/colthreepv/angular-media-player', 'created_at': datetime.datetime(2013, 7, 20, 13, 2, 49, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 3, 13, 21, 52, 8, tzinfo=datetime.timezone.utc)}
# {'name': 'salemdar/angular2-cookie', 'description': 'Implementation of Angular 1.x $cookies service to Angular 2', 'stars': 109, 'language': 'JavaScript', 'forks': 29, 'url': 'https://github.com/salemdar/angular2-cookie', 'created_at': datetime.datetime(2016, 3, 14, 12, 18, 57, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 7, 12, 0, 32, 6, tzinfo=datetime.timezone.utc)}
# {'name': 'lavinjj/angularjs-localizationservice', 'description': 'AngularJS Resource Localization Service', 'stars': 166, 'language': 'HTML', 'forks': 60, 'url': 'https://github.com/lavinjj/angularjs-localizationservice', 'created_at': datetime.datetime(2012, 12, 8, 20, 44, 53, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 1, 30, 19, 26, 32, tzinfo=datetime.timezone.utc)}
# {'name': 'ngcolombia/medellin', 'description': '⭐️ Repositorio oficial de Angular Medellín ⭐️', 'stars': 150, 'language': None, 'forks': 153, 'url': 'https://github.com/ngcolombia/medellin', 'created_at': datetime.datetime(2017, 4, 30, 16, 38, 25, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 11, 23, 15, 34, 19, tzinfo=datetime.timezone.utc)}
# {'name': 'ngOfficeUIFabric/ng-officeuifabric', 'description': 'Office UI Fabric (https://github.com/OfficeDev/office-ui-fabric) implementation for Angular', 'stars': 321, 'language': 'TypeScript', 'forks': 67, 'url': 'https://github.com/ngOfficeUIFabric/ng-officeuifabric', 'created_at': datetime.datetime(2015, 9, 12, 10, 19, 24, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 2, 28, 22, 30, 33, tzinfo=datetime.timezone.utc)}
# {'name': 'angular-pouchdb/angular-pouchdb', 'description': 'AngularJS v1.x wrapper for PouchDB', 'stars': 277, 'language': 'JavaScript', 'forks': 47, 'url': 'https://github.com/angular-pouchdb/angular-pouchdb', 'created_at': datetime.datetime(2014, 7, 24, 0, 50, 26, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 7, 20, 23, 15, 24, tzinfo=datetime.timezone.utc)}
# {'name': 'ruhley/angular-color-picker', 'description': 'Vanilla AngularJS Color Picker Directive with no requirement on jQuery', 'stars': 166, 'language': 'JavaScript', 'forks': 79, 'url': 'https://github.com/ruhley/angular-color-picker', 'created_at': datetime.datetime(2014, 11, 7, 3, 38, 25, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 6, 7, 2, 38, 17, tzinfo=datetime.timezone.utc)}
# {'name': 'johnpapa/hottowel-angular-typescript', 'description': 'As seen at //Build 2015 presented by Erich Gamma, Chris Dias and John Papa.', 'stars': 145, 'language': 'JavaScript', 'forks': 83, 'url': 'https://github.com/johnpapa/hottowel-angular-typescript', 'created_at': datetime.datetime(2015, 4, 18, 5, 57, 57, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2023, 11, 29, 2, 55, 43, tzinfo=datetime.timezone.utc)}
# {'name': 'lacolaco/ng-dynamic', 'description': 'dynamic contents projection in Angular', 'stars': 133, 'language': 'TypeScript', 'forks': 34, 'url': 'https://github.com/lacolaco/ng-dynamic', 'created_at': datetime.datetime(2016, 11, 14, 4, 53, 15, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 8, 2, 5, 54, 30, tzinfo=datetime.timezone.utc)}
# {'name': 'syncfusion/ej2-angular-ui-components', 'description': 'Syncfusion Angular UI components library offer more than 50+ cross-browser, responsive, and lightweight angular UI controls for building modern web applications. ', 'stars': 274, 'language': 'TypeScript', 'forks': 113, 'url': 'https://github.com/syncfusion/ej2-angular-ui-components', 'created_at': datetime.datetime(2018, 10, 31, 6, 9, 18, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 9, 10, 5, 35, 49, tzinfo=datetime.timezone.utc)}
# {'name': 'paulyoder/angular-bootstrap-show-errors', 'description': 'An Angular directive for Bootstrap to intelligently show form validation errors', 'stars': 331, 'language': 'JavaScript', 'forks': 78, 'url': 'https://github.com/paulyoder/angular-bootstrap-show-errors', 'created_at': datetime.datetime(2013, 12, 19, 19, 33, 20, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 3, 21, 17, 42, 52, tzinfo=datetime.timezone.utc)}
# {'name': 'angulartics/angulartics-google-analytics', 'description': 'Google Analytics plugin for Angulartics', 'stars': 133, 'language': 'JavaScript', 'forks': 86, 'url': 'https://github.com/angulartics/angulartics-google-analytics', 'created_at': datetime.datetime(2015, 7, 17, 21, 28, 27, tzinfo=datetime.timezone.utc), 'updated_at': datetime.datetime(2024, 1, 2, 2, 58, 36, tzinfo=datetime.timezone.utc)}

# %%
import matplotlib.pyplot as plt

# Função para processar o DataFrame e extrair as informações
def process_repositories(df):
    # Criar dicionário para armazenar os dados coletados
    data = {
        'repo_name': [],
        'weekly_commits': [],
        'monthly_commits': [],
        'yearly_commits': [],
        'open_issues': [],
        'closed_issues': [],
        'open_pulls': [],
        'closed_pulls': []
    }

    # Iterar sobre os repositórios no DataFrame
    max_repos = min(1000, len(df))
    for i in range(max_repos):
        repo_name = df['name'][i]
        print(repo_name)
        print("="*50)
        print("="*50)
        print("="*50)
        # Obter a frequência de commits
        commit_frequency = get_commit_frequency(repo_name)

        # Adicionar a frequência de commits ao dicionário de dados
        data['repo_name'].append(repo_name)
        data['weekly_commits'].append(sum(commit_frequency.values()) // 52)  # Aproximado
        data['monthly_commits'].append(sum(commit_frequency.values()) // 12)  # Aproximado
        data['yearly_commits'].append(sum(commit_frequency.values()))         # Total anual

        # Obter dados de contribuições e issues
        contributions_issues = get_contributions_issues(repo_name)
        data['open_issues'].append(contributions_issues['open_issues'])
        data['closed_issues'].append(contributions_issues['closed_issues'])
        data['open_pulls'].append(contributions_issues['open_pulls'])
        data['closed_pulls'].append(contributions_issues['closed_pulls'])

        # # Plotar os gráficos de commits e contribuições
        # plot_commit_frequency(commit_frequency, repo_name)
        # plot_issues_contributions(contributions_issues, repo_name)

    # Converter o dicionário para DataFrame
    df_results = pd.DataFrame(data)

    # Retornar o DataFrame resultante
    return df_results

# Suas funções anteriores
def get_commit_frequency(repo_name):
    repo = g.get_repo(repo_name)
    commits = repo.get_commits()

    commit_frequency = {}
    for commit in commits:
        date = commit.commit.author.date
        month = date.strftime("%Y-%m")
        if month not in commit_frequency:
            commit_frequency[month] = 0
        commit_frequency[month] += 1
    return commit_frequency

def get_contributions_issues(repo_name):
    repo = g.get_repo(repo_name)

    open_issues = repo.get_issues(state='open').totalCount
    closed_issues = repo.get_issues(state='closed').totalCount
    open_pulls = repo.get_pulls(state='open').totalCount
    closed_pulls = repo.get_pulls(state='closed').totalCount

    return {
        "open_issues": open_issues,
        "closed_issues": closed_issues,
        "open_pulls": open_pulls,
        "closed_pulls": closed_pulls
    }

# Função para plotar a frequência de commits
def plot_commit_frequency(commit_frequency, repo_name):
    dates = list(commit_frequency.keys())
    commit_counts = list(commit_frequency.values())

    plt.figure(figsize=(10, 5))
    plt.plot(dates, commit_counts, marker='o')
    plt.title(f"Commit Frequency for {repo_name}")
    plt.xlabel("Month")
    plt.ylabel("Number of Commits")
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Função para plotar contribuições de issues e pull requests
def plot_issues_contributions(contributions_issues, repo_name):
    labels = ['Open Issues', 'Closed Issues', 'Open Pull Requests', 'Closed Pull Requests']
    counts = [
        contributions_issues['open_issues'],
        contributions_issues['closed_issues'],
        contributions_issues['open_pulls'],
        contributions_issues['closed_pulls']
    ]

    plt.figure(figsize=(10, 6))
    plt.bar(labels, counts, color=['blue', 'green', 'orange', 'red'])
    plt.title(f"Issues and Pull Requests for {repo_name}")
    plt.xlabel("Category")
    plt.ylabel("Count")
    plt.show()

# Exemplo de uso da função
# Substitua 'df_angular' pelo DataFrame real que você está utilizando
df_results = process_repositories(df_material_ui)

# Salvar o DataFrame resultante em um arquivo CSV
df_results.to_csv('repo_commit_issues_data.csv', index=False)

print("Dados coletados e armazenados com sucesso.")
# Out:
# mui/material-ui
# ==================================================
# ==================================================
# ==================================================
# CosmicMind/Material
# ==================================================
# ==================================================
# ==================================================
# material-components/material-components-android
# ==================================================
# ==================================================
# ==================================================
# Request GET /repositories/75643096/commits?page=113 failed with 403: Forbidden
# Setting next backoff to 1141.997157s
# mdbootstrap/mdb-ui-kit
# ==================================================
# ==================================================
# ==================================================
# material-components/material-components-web
# ==================================================
# ==================================================
# ==================================================
# mui/material-ui-pickers
# ==================================================
# ==================================================
# ==================================================
# minimal-ui-kit/material-kit-react
# ==================================================
# ==================================================
# ==================================================
# museui/muse-ui
# ==================================================
# ==================================================
# ==================================================
# xotahal/react-native-material-ui
# ==================================================
# ==================================================
# ==================================================
# InvexGames/MaterialUI
# ==================================================
# ==================================================
# ==================================================
# mbrn/material-table
# ==================================================
# ==================================================
# ==================================================
# hperrin/svelte-material-ui
# ==================================================
# ==================================================
# ==================================================
# material-components/material-components-ios
# ==================================================
# ==================================================
# ==================================================
# creativetimofficial/material-kit
# ==================================================
# ==================================================
# ==================================================
# mancj/MaterialSearchBar
# ==================================================
# ==================================================
# ==================================================
# devias-io/material-kit-react
# ==================================================
# ==================================================
# ==================================================
# gregnb/mui-datatables
# ==================================================
# ==================================================
# ==================================================
# palexdev/MaterialFX
# ==================================================
# ==================================================
# ==================================================
# invertase/react-native-material-design
# ==================================================
# ==================================================
# ==================================================
# mdbootstrap/material-design-for-bootstrap
# ==================================================
# ==================================================
# ==================================================
# atom-material/atom-material-ui
# ==================================================
# ==================================================
# ==================================================
# flatlogic/react-material-admin
# ==================================================
# ==================================================
# ==================================================
# Yuvaleros/material-ui-dropzone
# ==================================================
# ==================================================
# ==================================================
# Learus/react-material-ui-carousel
# ==================================================
# ==================================================
# ==================================================
# creativetimofficial/vue-material-kit
# ==================================================
# ==================================================
# ==================================================
# erikras/redux-form-material-ui
# ==================================================
# ==================================================
# ==================================================
# zdhxiong/mdui
# ==================================================
# ==================================================
# ==================================================
# TeamWertarbyte/material-ui-chip-input
# ==================================================
# ==================================================
# ==================================================
# iamshaunjp/material-ui-tut
# ==================================================
# ==================================================
# ==================================================
# formsy/formsy-material-ui
# ==================================================
# ==================================================
# ==================================================
# material-components/material-components-flutter
# ==================================================
# ==================================================
# ==================================================
# react-theming/storybook-addon-material-ui
# ==================================================
# ==================================================
# ==================================================
# KevinVandy/material-react-table
# ==================================================
# ==================================================
# ==================================================
# skotlex/ffxiv-material-ui
# ==================================================
# ==================================================
# ==================================================
# turing-tech/MaterialScrollBar
# ==================================================
# ==================================================
# ==================================================
# KeepSafe/TapTargetView
# ==================================================
# ==================================================
# ==================================================
# rafaelhz/react-material-admin-template
# ==================================================
# ==================================================
# ==================================================
# atarw/material-ui-swing
# ==================================================
# ==================================================
# ==================================================
# Teradata/covalent
# ==================================================
# ==================================================
# ==================================================
# esnaultdev/MaterialValues
# ==================================================
# ==================================================
# ==================================================
# creativetimofficial/soft-ui-dashboard-react
# ==================================================
# ==================================================
# ==================================================
# JosephusPaye/Keen-UI
# ==================================================
# ==================================================
# ==================================================
# alexanmtz/material-sense
# ==================================================
# ==================================================
# ==================================================
# jason-liu22/netflix-clone-react-typescript
# ==================================================
# ==================================================
# ==================================================
# OnsenUI/OnsenUI
# ==================================================
# ==================================================
# ==================================================
# alexplumb/material-ui-phone-number
# ==================================================
# ==================================================
# ==================================================
# Sharlaan/material-ui-superselectfield
# ==================================================
# ==================================================
# ==================================================
# DevExpress/devextreme-reactive
# ==================================================
# ==================================================
# ==================================================
# atom-material/atom-material-syntax
# ==================================================
# ==================================================
# ==================================================
# Ramotion/paper-onboarding
# ==================================================
# ==================================================
# ==================================================
# RikkaW/MaterialPreference
# ==================================================
# ==================================================
# ==================================================
# ShapeLab/SwarmUI
# ==================================================
# ==================================================
# ==================================================
# mdbootstrap/mdb-react-ui-kit
# ==================================================
# ==================================================
# ==================================================
# mdbootstrap/mdb-angular-ui-kit
# ==================================================
# ==================================================
# ==================================================
# nativescript-community/ui-material-components
# ==================================================
# ==================================================
# ==================================================
# mui/material-ui-docs
# ==================================================
# ==================================================
# ==================================================
# Request GET /repositories/128474008/commits?page=191 failed with 403: Forbidden
# Setting next backoff to 2075.125383s
# afollestad/material-cab
# ==================================================
# ==================================================
# ==================================================
# jonatanklosko/material-ui-confirm
# ==================================================
# ==================================================
# ==================================================
# takanabe/react-redux-material_ui-boilerplate
# ==================================================
# ==================================================
# ==================================================
# devmahmud/material-ui-portfolio
# ==================================================
# ==================================================
# ==================================================
# TeamWertarbyte/material-ui-search-bar
# ==================================================
# ==================================================
# ==================================================
# daylerees/material-peacock
# ==================================================
# ==================================================
# ==================================================
# Droid-ify/client
# ==================================================
# ==================================================
# ==================================================
# TheComputerM/svelte-materialify
# ==================================================
# ==================================================
# ==================================================
# mdbootstrap/mdb-vue-ui-kit
# ==================================================
# ==================================================
# ==================================================
# NewOldMax/react-material-ui-form-validator
# ==================================================
# ==================================================
# ==================================================
# unicef/material-ui-currency-textfield
# ==================================================
# ==================================================
# ==================================================
# PacktPublishing/React-Material-UI-Cookbook
# ==================================================
# ==================================================
# ==================================================
# hyojin/material-ui-datatables
# ==================================================
# ==================================================
# ==================================================
# Suleiman19/Android-Material-Design-for-pre-Lollipop
# ==================================================
# ==================================================
# ==================================================
# stackworx/formik-mui
# ==================================================
# ==================================================
# ==================================================
# AnthonyNahas/ngx-auth-firebaseui
# ==================================================
# ==================================================
# ==================================================
# codypearce/material-bread
# ==================================================
# ==================================================
# ==================================================
# codedthemes/berry-free-react-admin-template
# ==================================================
# ==================================================
# ==================================================
# skclusive/Skclusive.Material.Component
# ==================================================
# ==================================================
# ==================================================
# niuware/mui-rte
# ==================================================
# ==================================================
# ==================================================
# TeamWertarbyte/material-ui-image
# ==================================================
# ==================================================
# ==================================================
# matyunya/smelte
# ==================================================
# ==================================================
# ==================================================
# xotahal/react-native-material-ui-demo-app
# ==================================================
# ==================================================
# ==================================================
# qiujuer/Genius-Android
# ==================================================
# ==================================================
# ==================================================
# vincenzopalazzo/material-ui-swing
# ==================================================
# ==================================================
# ==================================================
# kobakei/MaterialFabSpeedDial
# ==================================================
# ==================================================
# ==================================================
# uilibrary/matx-react
# ==================================================
# ==================================================
# ==================================================
# dunky11/react-saas-template
# ==================================================
# ==================================================
# ==================================================
# Ramotion/expanding-collection
# ==================================================
# ==================================================
# ==================================================
# RoyTimes/materialize_blog
# ==================================================
# ==================================================
# ==================================================
# jcoreio/material-ui-popup-state
# ==================================================
# ==================================================
# ==================================================
# primefaces/primereact
# ==================================================
# ==================================================
# ==================================================
# madvas/cljs-react-material-ui
# ==================================================
# ==================================================
# ==================================================
# mikbry/material-ui-color
# ==================================================
# ==================================================
# ==================================================
# goemen/react-material-ui-typescript
# ==================================================
# ==================================================
# ==================================================
# lookfirst/mui-rff
# ==================================================
# ==================================================
# ==================================================
# StratoDem/sd-material-ui
# ==================================================
# ==================================================
# ==================================================
# adrianhajdin/project_youtube_clone
# ==================================================
# ==================================================
# ==================================================
# bradtraversy/react_step_form
# ==================================================
# ==================================================
# ==================================================
# richzertuche/ZMaterialDesignUIButton
# ==================================================
# ==================================================
# ==================================================
# siriwatknp/mui-treasury
# ==================================================
# ==================================================
# ==================================================
# puranjayjain/react-materialui-notifications
# ==================================================
# ==================================================
# ==================================================
# Aditya94A/Morphing-Material-Dialogs
# ==================================================
# ==================================================
# ==================================================
# nadunindunil/awesome-material-ui
# ==================================================
# ==================================================
# ==================================================
# Request GET /repos/nadunindunil/awesome-material-ui failed with 403: Forbidden
# Setting next backoff to 2429.427608s
# yamankatby/react-native-material
# ==================================================
# ==================================================
# ==================================================
# wenzhixin/bootstrap-table
# ==================================================
# ==================================================
# ==================================================
# TeamWertarbyte/mdi-material-ui
# ==================================================
# ==================================================
# ==================================================
# aldabil21/react-scheduler
# ==================================================
# ==================================================
# ==================================================
# arttuka/reagent-material-ui
# ==================================================
# ==================================================
# ==================================================
# emkay/material-ui-table-edit
# ==================================================
# ==================================================
# ==================================================
# 720kb/hubuntu-ui
# ==================================================
# ==================================================
# ==================================================
# Ramotion/circle-menu
# ==================================================
# ==================================================
# ==================================================
# hupe1980/gatsby-plugin-material-ui
# ==================================================
# ==================================================
# ==================================================
# techniq/mui-virtualized-table
# ==================================================
# ==================================================
# ==================================================
# bloomui/tokyo-free-white-react-admin-dashboard
# ==================================================
# ==================================================
# ==================================================
# ccforward/rubik
# ==================================================
# ==================================================
# ==================================================
# dpcdpc11/gravit-material-ui-kit
# ==================================================
# ==================================================
# ==================================================
# florent37/Shrine-MaterialDesign2
# ==================================================
# ==================================================
# ==================================================
# treeder/material
# ==================================================
# ==================================================
# ==================================================
# vikignt/svelte-mui
# ==================================================
# ==================================================
# ==================================================
# m6v3l9/react-material-admin
# ==================================================
# ==================================================
# ==================================================
# swordev/suid
# ==================================================
# ==================================================
# ==================================================
# gpbl/material-ui-sass
# ==================================================
# ==================================================
# ==================================================
# joaopaulomoraes/nextjs-with-redux-and-material-ui
# ==================================================
# ==================================================
# ==================================================
# ggascoigne/react-table-example
# ==================================================
# ==================================================
# ==================================================
# TeamWertarbyte/material-ui-time-picker
# ==================================================
# ==================================================
# ==================================================
# Zaelot-Inc/ui-libraries
# ==================================================
# ==================================================
# ==================================================
# Ramotion/circle-menu-android
# ==================================================
# ==================================================
# ==================================================
# async-labs/builderbook
# ==================================================
# ==================================================
# ==================================================
# creativetimofficial/ct-material-kit-pro
# ==================================================
# ==================================================
# ==================================================
# dohomi/react-hook-form-mui
# ==================================================
# ==================================================
# ==================================================
# Ramotion/expanding-collection-android
# ==================================================
# ==================================================
# ==================================================
# bill-ahmed/qbit-matUI
# ==================================================
# ==================================================
# ==================================================
# themightykitten/ruTorrent-MaterialDesign
# ==================================================
# ==================================================
# ==================================================
# StevenDXC/DxLoadingButton
# ==================================================
# ==================================================
# ==================================================
# JackGit/material-ui-vue
# ==================================================
# ==================================================
# ==================================================
# trananhtuat/fullstack-kanban-app
# ==================================================
# ==================================================
# ==================================================
# balmjs/balm-ui
# ==================================================
# ==================================================
# ==================================================
# adeelibr/react-starter-kit
# ==================================================
# ==================================================
# ==================================================
# tsurupin/portfolio
# ==================================================
# ==================================================
# ==================================================
# florent37/ArcLayout
# ==================================================
# ==================================================
# ==================================================
# dternyak/React-Redux-Flask
# ==================================================
# ==================================================
# ==================================================
# nblthree/nextjs-with-material-ui-and-styled-components
# ==================================================
# ==================================================
# ==================================================
# fable-compiler/fable-elmish-electron-material-ui-demo
# ==================================================
# ==================================================
# ==================================================
# HarinTrivedi/FABRevealMenu-master
# ==================================================
# ==================================================
# ==================================================
# varletjs/varlet
# ==================================================
# ==================================================
# ==================================================
# material-table-core/core
# ==================================================
# ==================================================
# ==================================================
# gorhom/react-native-paper-onboarding
# ==================================================
# ==================================================
# ==================================================
# treetips/typescript-nextjs-redux-material-ui-example
# ==================================================
# ==================================================
# ==================================================
# A-l-y-l-e/Alyle-UI
# ==================================================
# ==================================================
# ==================================================
# masastack/MASA.Blazor
# ==================================================
# ==================================================
# ==================================================
# hiteshsahu/Material-UpVote
# ==================================================
# ==================================================
# ==================================================
# mater1996/sc-ui
# ==================================================
# ==================================================
# ==================================================
# tuckerconnelly/carbon-ui
# ==================================================
# ==================================================
# ==================================================
# async-labs/saas
# ==================================================
# ==================================================
# ==================================================
# sugarac/react-cnodejs.org
# ==================================================
# ==================================================
# ==================================================
# kireerik/razzle-material-ui-styled-example
# ==================================================
# ==================================================
# ==================================================
# harryho/react-crm
# ==================================================
# ==================================================
# ==================================================
# sweetalert2/sweetalert2-themes
# ==================================================
# ==================================================
# ==================================================
# ui-schema/ui-schema
# ==================================================
# ==================================================
# ==================================================
# gopinav/React-MUI-Tutorials
# ==================================================
# ==================================================
# ==================================================
# Ramotion/cardslider-android
# ==================================================
# ==================================================
# ==================================================
# florent37/BubbleTab
# ==================================================
# ==================================================
# ==================================================
# mayneyao/gine-blog
# ==================================================
# ==================================================
# ==================================================
# radzenhq/radzen-blazor
# ==================================================
# ==================================================
# ==================================================
# ofarukcaki/dataleaks
# ==================================================
# ==================================================
# ==================================================
# adminmart/Modernize-Nextjs-Free
# ==================================================
# ==================================================
# ==================================================
# developit/preact-mdl
# ==================================================
# ==================================================
# ==================================================
# p32929/portfolio-v2
# ==================================================
# ==================================================
# ==================================================
# vuetifyjs/vuetify
# ==================================================
# ==================================================
# ==================================================
# fiffty/react-treeview-mui
# ==================================================
# ==================================================
# ==================================================
# sjdemartini/mui-tiptap
# ==================================================
# ==================================================
# ==================================================
# JunichiT/JTMaterialSwitch
# ==================================================
# ==================================================
# ==================================================
# Idean/Flutter-Neumorphic
# ==================================================
# ==================================================
# ==================================================
# angular-material-extensions/password-strength
# ==================================================
# ==================================================
# ==================================================
# sardapv/angular-material-starter-template
# ==================================================
# ==================================================
# ==================================================
# elkozmon/zoonavigator
# ==================================================
# ==================================================
# ==================================================
# cfnz/muirwik
# ==================================================
# ==================================================
# ==================================================
# CosmicMind/Motion
# ==================================================
# ==================================================
# ==================================================
# s1varam/pokedex
# ==================================================
# ==================================================
# ==================================================
# pregiotek/ion-floating-menu
# ==================================================
# ==================================================
# ==================================================
# siriwatknp/mui-layout
# ==================================================
# ==================================================
# ==================================================
# flippingbitss/react-daterange-picker
# ==================================================
# ==================================================
# ==================================================
# wpcodevo/JWT_Authentication_React
# ==================================================
# ==================================================
# ==================================================
# IgniteUI/igniteui-angular
# ==================================================
# ==================================================
# ==================================================
# Request GET /repositories/51516387/commits?page=135 failed with 403: Forbidden
# Setting next backoff to 2025.799416s
# zephyo/UI-Blur-LWRP-2020
# ==================================================
# ==================================================
# ==================================================
# ShivamJoker/Ylight-Music
# ==================================================
# ==================================================
# ==================================================
# kysonic/riot-mui
# ==================================================
# ==================================================
# ==================================================
# AtomMaterialUI/a-file-icon-idea
# ==================================================
# ==================================================
# ==================================================
# tudorconstantin/knests
# ==================================================
# ==================================================
# ==================================================
# steniowagner/store-system
# ==================================================
# ==================================================
# ==================================================
# viclafouch/mui-tel-input
# ==================================================
# ==================================================
# ==================================================
# Ramotion/paper-switch
# ==================================================
# ==================================================
# ==================================================
# themeselection/materio-mui-nextjs-admin-template-free
# ==================================================
# ==================================================
# ==================================================
# bluzi/awesome-google-tasks
# ==================================================
# ==================================================
# ==================================================
# williamluke4/Nitro
# ==================================================
# ==================================================
# ==================================================
# fujiyuu75/Sequent
# ==================================================
# ==================================================
# ==================================================
# react-theming/storybook-addon
# ==================================================
# ==================================================
# ==================================================
# lorensr/react-payment
# ==================================================
# ==================================================
# ==================================================
# fsojitra/Registration-Login-and-CRUD-Action-using-MERN-stack
# ==================================================
# ==================================================
# ==================================================
# mdbootstrap/perfect-scrollbar
# ==================================================
# ==================================================
# ==================================================
# kealiu/ComfyUI-ZeroShot-MTrans
# ==================================================
# ==================================================
# ==================================================
# okld/streamlit-elements
# ==================================================
# ==================================================
# ==================================================
# salomonelli/personal-portfolio
# ==================================================
# ==================================================
# ==================================================
# kiri-art/stable-diffusion-react-nextjs-mui-pwa
# ==================================================
# ==================================================
# ==================================================
# kivymd/KivyMD
# ==================================================
# ==================================================
# ==================================================
# Ramotion/react-native-circle-menu
# ==================================================
# ==================================================
# ==================================================
# DesignRevision/shards-dashboard
# ==================================================
# ==================================================
# ==================================================
# HendrixString/adobe-cep-react-create
# ==================================================
# ==================================================
# ==================================================
# merikbest/twitter-spring-reactjs
# ==================================================
# ==================================================
# ==================================================
# aribudin/tailmater
# ==================================================
# ==================================================
# ==================================================
# adrianhajdin/project_corona_tracker
# ==================================================
# ==================================================
# ==================================================
# CharlesStover/use-mui
# ==================================================
# ==================================================
# ==================================================
# faisalnazik/Django-React-Redux-Boilerplate
# ==================================================
# ==================================================
# ==================================================
# hwding/android-art
# ==================================================
# ==================================================
# ==================================================
# tsinis/colors_ai
# ==================================================
# ==================================================
# ==================================================
# saltyshiomix/ark
# ==================================================
# ==================================================
# ==================================================
# netzwerg/react-you-do-you
# ==================================================
# ==================================================
# ==================================================
# bareynol/mui-theme-creator
# ==================================================
# ==================================================
# ==================================================
# unosquare/tubular-react
# ==================================================
# ==================================================
# ==================================================
# emre1512/Noty
# ==================================================
# ==================================================
# ==================================================
# Rev-RoastedDuck/Qt-RoastedDuck-Widgets
# ==================================================
# ==================================================
# ==================================================
# vip-git/universal-json-schema
# ==================================================
# ==================================================
# ==================================================
# LDRAlighieri/Corbind
# ==================================================
# ==================================================
# ==================================================
# dvikas/nextjs-graphql-adminpanel
# ==================================================
# ==================================================
# ==================================================
# Niyko/Hydra-Dark-Theme-for-Adminer
# ==================================================
# ==================================================
# ==================================================
# Taiizor/ReaLTaiizor
# ==================================================
# ==================================================
# ==================================================
# laotan7237/EasyReader
# ==================================================
# ==================================================
# ==================================================
# wq/wq
# ==================================================
# ==================================================
# ==================================================
# arihant-jain-09/discord-clone
# ==================================================
# ==================================================
# ==================================================
# align-capstone/align
# ==================================================
# ==================================================
# ==================================================
# janishar/react-app-architecture
# ==================================================
# ==================================================
# ==================================================
# hoothin/SearchJumper
# ==================================================
# ==================================================
# ==================================================
# wq/wq.app
# ==================================================
# ==================================================
# ==================================================
# sessionboy/sinn
# ==================================================
# ==================================================
# ==================================================
# stevdza-san/MessageBarCompose
# ==================================================
# ==================================================
# ==================================================
# Lowae/Design-WanAndroid
# ==================================================
# ==================================================
# ==================================================
# meta-magic/amexio.github.io
# ==================================================
# ==================================================
# ==================================================
# puxiao/notes
# ==================================================
# ==================================================
# ==================================================
# LemonIT66/idea_activate
# ==================================================
# ==================================================
# ==================================================
# loper7/tablayout-ext
# ==================================================
# ==================================================
# ==================================================
# mob-sakai/CompositeCanvasRenderer
# ==================================================
# ==================================================
# ==================================================
# limingpu123456/FileMaster
# ==================================================
# ==================================================
# ==================================================
# collegeconnect/CollegeConnect
# ==================================================
# ==================================================
# ==================================================
# itsmartashub/floristyle
# ==================================================
# ==================================================
# ==================================================
# cirosantilli/china-dictatorship
# ==================================================
# ==================================================
# ==================================================
# gege-circle/home
# ==================================================
# ==================================================
# ==================================================
# cirosantilli/china-dictatorhsip-7
# ==================================================
# ==================================================
# ==================================================
# cheezcharmer/chinese-dictatorship
# ==================================================
# ==================================================
# ==================================================
# chrisneagu/FTC-Skystone-Dark-Angels-Romania-2020
# ==================================================
# ==================================================
# ==================================================
# Sfedfcv/redesigned-pancake
# ==================================================
# ==================================================
# ==================================================
# ---------------------------------------------------------------------------
# GithubException                           Traceback (most recent call last)
# Cell In[2], line 113
#     109     plt.show()
#     111 # Exemplo de uso da função
#     112 # Substitua 'df_angular' pelo DataFrame real que você está utilizando
# --> 113 df_results = process_repositories(df_material_ui)
#     115 # Salvar o DataFrame resultante em um arquivo CSV
#     116 df_results.to_csv('repo_commit_issues_data.csv', index=False)
#
# Cell In[2], line 26, in process_repositories(df)
#      24 print("="*50)
#      25 # Obter a frequência de commits
# ---> 26 commit_frequency = get_commit_frequency(repo_name)
#      28 # Adicionar a frequência de commits ao dicionário de dados
#      29 data['repo_name'].append(repo_name)
#
# Cell In[2], line 57, in get_commit_frequency(repo_name)
#      54 commits = repo.get_commits()
#      56 commit_frequency = {}
# ---> 57 for commit in commits:
#      58     date = commit.commit.author.date
#      59     month = date.strftime("%Y-%m")
#
# File ~\AppData\Roaming\Python\Python311\site-packages\github\PaginatedList.py:84, in PaginatedListBase.__iter__(self)
#      82 yield from self.__elements
#      83 while self._couldGrow():
# ---> 84     newElements = self._grow()
#      85     yield from newElements
#
# File ~\AppData\Roaming\Python\Python311\site-packages\github\PaginatedList.py:95, in PaginatedListBase._grow(self)
#      94 def _grow(self) -> List[T]:
# ---> 95     newElements = self._fetchNextPage()
#      96     self.__elements += newElements
#      97     return newElements
#
# File ~\AppData\Roaming\Python\Python311\site-packages\github\PaginatedList.py:244, in PaginatedList._fetchNextPage(self)
#     243 def _fetchNextPage(self) -> List[T]:
# --> 244     headers, data = self.__requester.requestJsonAndCheck(
#     245         "GET", self.__nextUrl, parameters=self.__nextParams, headers=self.__headers
#     246     )
#     247     data = data if data else []
#     248     return self._getPage(data, headers)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\github\Requester.py:550, in Requester.requestJsonAndCheck(self, verb, url, parameters, headers, input)
#     542 def requestJsonAndCheck(
#     543     self,
#     544     verb: str,
#    (...)
#     548     input: Optional[Any] = None,
#     549 ) -> Tuple[Dict[str, Any], Any]:
# --> 550     return self.__check(*self.requestJson(verb, url, parameters, headers, input, self.__customConnection(url)))
#
# File ~\AppData\Roaming\Python\Python311\site-packages\github\Requester.py:611, in Requester.__check(self, status, responseHeaders, output)
#     609 data = self.__structuredFromJson(output)
#     610 if status >= 400:
# --> 611     raise self.createException(status, responseHeaders, data)
#     612 return responseHeaders, data
#
# GithubException: 409 {"message": "Git Repository is empty.", "documentation_url": "https://docs.github.com/rest/commits/commits#list-commits", "status": "409"}
